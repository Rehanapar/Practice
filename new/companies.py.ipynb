# %%
# // pip3 install requests
import requests


# print(response)
# // pip3 install beautifulsoup4
from bs4 import BeautifulSoup

# // pip3 install pandas
import pandas as pd

books = []

for i in range(1,5):
  url = f"https://books.toscrape.com/catalogue/page-{i}.html"
  response = requests.get(url)
  response = response.content
  soup = BeautifulSoup(response, 'html.parser')
  ol = soup.find('ol')
  articles = ol.find_all('article', class_='product_pod')
  for article in articles:
    image = article.find('img')
    title = image.attrs['alt']
    starTag = article.find('p')
    star = starTag['class'][1]
    price = article.find('p', class_='price_color').text
    price = float(price[1:])
    books.append([title, star, price])
    

df = pd.DataFrame(books, columns=['Title', 'Star Rating', 'Price'])
df.to_csv('books.csv')
print(df)
# Out:
#                                                 Title Star Rating  Price
# 0                                A Light in the Attic       Three  51.77
# 1                                  Tipping the Velvet         One  53.74
# 2                                          Soumission         One  50.10
# 3                                       Sharp Objects        Four  47.82
# 4               Sapiens: A Brief History of Humankind        Five  54.23
# ..                                                ...         ...    ...
# 75                                           Security         Two  39.25
# 76      Saga, Volume 6 (Saga (Collected Editions) #6)       Three  25.02
# 77      Saga, Volume 5 (Saga (Collected Editions) #5)         Two  51.04
# 78  Reskilling America: Learning to Labor in the T...         Two  19.83
# 79  Rat Queens, Vol. 3: Demons (Rat Queens (Collec...       Three  50.40
#
# [80 rows x 3 columns]

# %%
response = response.content

# %%
# soup = BeautifulSoup(response, "html.parser")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

company = []
com = ["INFY.NS", "TCS", "CAP.PA", "CTS", "HCL.DE"]

for i in com:
    url = f"https://finance.yahoo.com/quote/{com}/news/"
    response = requests.get(url)
    response = response.content
    soup = BeautifulSoup(response, 'html.parser')
    
    headline = soup.find('h3', class_='clamp  yf-1e4au4k')
    p_tag = soup.find('p', class_='clamp  yf-1e4au4k')
    publishing_info = soup.find('div', class_='publishing font-condensed yf-da5pxu')
    for ticker, change in zip(tickers, changes):
        ticker_symbol = ticker.find('span', class_='symbol').text
        percentage_change = change.find('span').text
        print(f"{ticker_symbol}: {percentage_change}")
#     for article in articles:
#         image = article.find('a')
#         title = image.attrs['h3']
#         starTag = article.find('p')
#         star = starTag['class'][1]
#         company.append([title, star])


# df = pd.DataFrame(company, columns=['Title', 'Star Rating'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 14
#      12 soup = BeautifulSoup(response, 'html.parser')
#      13 ol = soup.find('ul')
# ---> 14 articles = ol.find_all('li', class_="stream-item  yf-7rcxn")
#      16 for article in articles:
#      17     image = article.find('a')
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
import requests
from bs4 import BeautifulSoup

url = "https://finance.yahoo.com/quote/INFY.NS/news/"

response = requests.get(url)

soup = BeautifulSoup(response.content, "html.parser")

# %%
<li class="stream-item  yf-7rcxn">
<section class="container sz-x-large stream yf-1e4au4k responsive" data-testid="storyitem" role="article">
<a class="subtle-link fin-size-small thumb yf-13p9sh2" data-ylk="elm:img;elmt:link;itc:0;ct:story;g:dbe0bf55-0ab4-3968-a6c0-3069f9027fee;slk:The%20Weekly%20Closeout%3A%20Pacsun%20names%20CFO%2C%20Abercrombie%20posts%20%E2%80%98record%E2%80%99%20Q2%20net%20sales;sec:qsp-news;subsec:all;cpos:1" href="https://finance.yahoo.com/news/weekly-closeout-pacsun-names-cfo-123600749.html" aria-label="The Weekly Closeout: Pacsun names CFO, Abercrombie posts ‘record’ Q2 net sales" title="The Weekly Closeout: Pacsun names CFO, Abercrombie posts ‘record’ Q2 net sales" data-rapid_p="19" data-v9y="1"><div style="display: contents; --border-radius: var(--border-radius-m); --aspect-ratio: 4/3;"> 
<img class="tw-bg-opacity-25  yf-13q9uv1" alt="The Weekly Closeout: Pacsun names CFO, Abercrombie posts ‘record’ Q2 net sales" src="https://s.yimg.com/uu/api/res/1.2/YObA2B6sUykZpsGHTnqFHA--~B/Zmk9c3RyaW07aD0xMjY7cT04MDt3PTE2ODthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/retail_dive_367/74a5eff6e0492406e66ea1fe6c3f2f8c.cf.webp" srcset="https://s.yimg.com/uu/api/res/1.2/KIV7dvm_0cVo6UamHPYCkQ--~B/Zmk9c3RyaW07aD0yNTI7cT04MDt3PTMzNjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/retail_dive_367/74a5eff6e0492406e66ea1fe6c3f2f8c.cf.webp 2x" fetchpriority="auto" loading="lazy">
</div>   
</a>
<div class="content yf-1e4au4k"><a class="subtle-link fin-size-small titles noUnderline yf-13p9sh2" data-ylk="elm:hdln;elmt:link;itc:0;ct:story;g:dbe0bf55-0ab4-3968-a6c0-3069f9027fee;slk:The%20Weekly%20Closeout%3A%20Pacsun%20names%20CFO%2C%20Abercrombie%20posts%20%E2%80%98record%E2%80%99%20Q2%20net%20sales;sec:qsp-news;subsec:all;cpos:1" href="https://finance.yahoo.com/news/weekly-closeout-pacsun-names-cfo-123600749.html" aria-label="The Weekly Closeout: Pacsun names CFO, Abercrombie posts ‘record’ Q2 net sales" title="The Weekly Closeout: Pacsun names CFO, Abercrombie posts ‘record’ Q2 net sales" data-rapid_p="20" data-v9y="1"><h3 class="clamp  yf-1e4au4k">The Weekly Closeout: Pacsun names CFO, Abercrombie posts ‘record’ Q2 net sales</h3> <p class="clamp  yf-1e4au4k">The teen retailer hired BowFlex, Inc. veteran&nbsp;Aina Konold,&nbsp;while the apparel company saw sales increase 21% year over year to $1.1 billion.</p> </a> <div class="footer yf-1e4au4k"> 
<div class="publishing font-condensed yf-da5pxu">Retail Dive <i aria-hidden="true" data-svelte-h="svelte-sg6bkb">•</i> 10 days ago</div> <div class="taxonomy-links yf-13tszyc"><a data-testid="ticker-container" class="ticker x-small hover2 border streaming yf-ravs5v" aria-label="ANF" data-ylk="elm:qte;elmt:link;itc:0;sec:qsp-news;slk:ANF;subsec:all;cpos:1" href="/quote/ANF/" title="ANF" data-rapid_p="21" data-v9y="1"> <div class="name yf-ravs5v"><span class="symbol yf-ravs5v">ANF</span> </div> <fin-streamer class="percentChange yf-ravs5v" data-symbol="ANF" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-tstyle="default" active=""><span class="d60f3b00 c4af00a5 c956d6fc">+3.04%</span></fin-streamer> </a><a data-testid="ticker-container" class="ticker x-small hover2 border streaming yf-ravs5v" aria-label="TCS" data-ylk="elm:qte;elmt:link;itc:0;sec:qsp-news;slk:TCS;subsec:all;cpos:1" href="/quote/TCS/" title="TCS" data-rapid_p="22" data-v9y="1">
<div class="name yf-ravs5v"><span class="symbol yf-ravs5v">TCS</span> </div> <fin-streamer class="percentChange yf-ravs5v" data-symbol="TCS" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-tstyle="default" active="">
<span class="d60f3b00 d5882186">-2.25%</span></fin-streamer> 
</a> 
</div>
</div>
</div>
</section>
</li>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = f"https://finance.yahoo.com/quote/TCS/news/"
response = requests.get(url)
response = response.content
soup = BeautifulSoup(response, 'html.parser')

headline = soup.find('h3', class_='clamp  yf-1e4au4k')
p_tag = soup.find('p', class_='clamp  yf-1e4au4k')
publishing_info = soup.find('div', class_='publishing font-condensed yf-da5pxu')
if headline:
    print("Headline:", headline.text)
if p_tag:
    print("Description:", p_tag.text)
if publishing_info:
    print("Published:", publishing_info.text)

tickers = soup.find_all('div', class_='name yf-ravs5v')
changes = soup.find_all('fin-streamer', class_='percentChange yf-ravs5v')
for ticker, change in zip(tickers, changes):
    ticker_symbol = ticker.find('span', class_='symbol').text
    percentage_change = change.find('span').text
    print(f"{ticker_symbol}: {percentage_change}")
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

company = []
com = ["INFY.NS", "TCS", "CAP.PA", "CTS", "HCL.DE"]

for i in com:

        url = f"https://finance.yahoo.com/quote/{com}/news/"
        response = requests.get(url)
        response = response.content
        soup = BeautifulSoup(response, 'html.parser')

        headline = soup.find('h3', class_='clamp  yf-1e4au4k')
        p_tag = soup.find('p', class_='clamp  yf-1e4au4k')
        publishing_info = soup.find('div', class_='publishing font-condensed yf-da5pxu')
        if headline:
            print("Headline:", headline.text)
        if p_tag:
            print("Description:", p_tag.text)
        if publishing_info:
            print("Published:", publishing_info.text)

        tickers = soup.find_all('div', class_='name yf-ravs5v')
        changes = soup.find_all('fin-streamer', class_='percentChange yf-ravs5v')
        for ticker, change in zip(tickers, changes):
            ticker_symbol = ticker.find('span', class_='symbol').text
            percentage_change = change.find('span').text
            print(f"{ticker_symbol}: {percentage_change}")

        company.append([headline, p_tag,  publishing_info])

df = pd.DataFrame(company, columns=['Title', 'Description', 'days'])
df.to_csv("company.csv")
print(df)
# Out:
#   Title Description  days
# 0  None        None  None
# 1  None        None  None
# 2  None        None  None
# 3  None        None  None
# 4  None        None  None

# %%
from bs4 import BeautifulSoup

# Example HTML snippet
html_content = '''
<li class="stream-item  yf-7rcxn">
<section class="container sz-x-large stream yf-1e4au4k responsive" data-testid="storyitem" role="article">
<a class="subtle-link fin-size-small thumb yf-13p9sh2" data-ylk="elm:img;elmt:link;itc:0;ct:story;g:dbe0bf55-0ab4-3968-a6c0-3069f9027fee;slk:The%20Weekly%20Closeout%3A%20Pacsun%20names%20CFO%2C%20Abercrombie%20posts%20%E2%80%98record%E2%80%99%20Q2%20net%20sales;sec:qsp-news;subsec:all;cpos:1" href="https://finance.yahoo.com/news/weekly-closeout-pacsun-names-cfo-123600749.html" aria-label="The Weekly Closeout: Pacsun names CFO, Abercrombie posts ‘record’ Q2 net sales" title="The Weekly Closeout: Pacsun names CFO, Abercrombie posts ‘record’ Q2 net sales" data-rapid_p="19" data-v9y="1">
<div style="display: contents; --border-radius: var(--border-radius-m); --aspect-ratio: 4/3;"> 
<img class="tw-bg-opacity-25  yf-13q9uv1" alt="The Weekly Closeout: Pacsun names CFO, Abercrombie posts ‘record’ Q2 net sales" src="https://s.yimg.com/uu/api/res/1.2/YObA2B6sUykZpsGHTnqFHA--~B/Zmk9c3RyaW07aD0xMjY7cT04MDt3PTE2ODthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/retail_dive_367/74a5eff6e0492406e66ea1fe6c3f2f8c.cf.webp" srcset="https://s.yimg.com/uu/api/res/1.2/KIV7dvm_0cVo6UamHPYCkQ--~B/Zmk9c3RyaW07aD0yNTI7cT04MDt3PTMzNjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/retail_dive_367/74a5eff6e0492406e66ea1fe6c3f2f8c.cf.webp 2x" fetchpriority="auto" loading="lazy">
</div>   
</a>
<div class="content yf-1e4au4k">
<a class="subtle-link fin-size-small titles noUnderline yf-13p9sh2" data-ylk="elm:hdln;elmt:link;itc:0;ct:story;g:dbe0bf55-0ab4-3968-a6c0-3069f9027fee;slk:The%20Weekly%20Closeout%3A%20Pacsun%20names%20CFO%2C%20Abercrombie%20posts%20%E2%80%98record%E2%80%99%20Q2%20net%20sales;sec:qsp-news;subsec:all;cpos:1" href="https://finance.yahoo.com/news/weekly-closeout-pacsun-names-cfo-123600749.html" aria-label="The Weekly Closeout: Pacsun names CFO, Abercrombie posts ‘record’ Q2 net sales" title="The Weekly Closeout: Pacsun names CFO, Abercrombie posts ‘record’ Q2 net sales" data-rapid_p="20" data-v9y="1">
<h3 class="clamp  yf-1e4au4k">The Weekly Closeout: Pacsun names CFO, Abercrombie posts ‘record’ Q2 net sales</h3> 
<p class="clamp  yf-1e4au4k">The teen retailer hired BowFlex, Inc. veteran&nbsp;Aina Konold,&nbsp;while the apparel company saw sales increase 21% year over year to $1.1 billion.</p> 
</a> 
<div class="footer yf-1e4au4k">
<div class="publishing font-condensed yf-da5pxu">Retail Dive <i aria-hidden="true" data-svelte-h="svelte-sg6bkb">•</i> 10 days ago</div>
<div class="taxonomy-links yf-13tszyc">
<a data-testid="ticker-container" class="ticker x-small hover2 border streaming yf-ravs5v" aria-label="ANF" data-ylk="elm:qte;elmt:link;itc:0;sec:qsp-news;slk:ANF;subsec:all;cpos:1" href="/quote/ANF/" title="ANF" data-rapid_p="21" data-v9y="1"> 
<div class="name yf-ravs5v"><span class="symbol yf-ravs5v">ANF</span></div>
<fin-streamer class="percentChange yf-ravs5v" data-symbol="ANF" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-tstyle="default" active="">
<span class="d60f3b00 c4af00a5 c956d6fc">+3.04%</span>
</fin-streamer> 
</a>
<a data-testid="ticker-container" class="ticker x-small hover2 border streaming yf-ravs5v" aria-label="TCS" data-ylk="elm:qte;elmt:link;itc:0;sec:qsp-news;slk:TCS;subsec:all;cpos:1" href="/quote/TCS/" title="TCS" data-rapid_p="22" data-v9y="1">
<div class="name yf-ravs5v"><span class="symbol yf-ravs5v">TCS</span></div>
<fin-streamer class="percentChange yf-ravs5v" data-symbol="TCS" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-tstyle="default" active="">
<span class="d60f3b00 d5882186">-2.25%</span>
</fin-streamer>
</a>
</div>
</div>
</div>
</section>
</li>
'''

# Create BeautifulSoup object
soup = BeautifulSoup(html_content, 'html.parser')

# Access the h3 headline
headline = soup.find('h3', class_='clamp  yf-1e4au4k')
print("Headline:", headline.text.strip())

# Access the publishing date
publishing_info = soup.find('div', class_='publishing font-condensed yf-da5pxu')
print("Published:", publishing_info.text.strip())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[82], line 44
#      42 # Access the h3 headline
#      43 headline = soup.find('h3', class_='clamp  yf-1e4au4k')
# ---> 44 print("Headline:", headline.text.strip())
#      46 # Access the publishing date
#      47 publishing_info = soup.find('div', class_='publishing font-condensed yf-da5pxu')
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
url = "https://finance.yahoo.com/quote/TCS/news/"
response = requests.get(url)
response = response.content
soup = BeautifulSoup(response, 'html.parser')

headline = soup.find('h3', class_='clamp  yf-1e4au4k')
p_tag = soup.find('p', class_='clamp  yf-1e4au4k')
publishing_info = soup.find('div', class_='publishing font-condensed yf-da5pxu')
if headline:
    print("Headline:", headline.text)
if p_tag:
    print("Description:", p_tag.text)
if publishing_info:
    print("Published:", publishing_info.text)

# %%
url = f"https://finance.yahoo.com/quote/TCS/news/"
response = requests.get(url)
response = response.content
soup = BeautifulSoup(response, 'html.parser')
soup

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
 
company = []
com = ["INFY.NS", "TCS", "CAP.PA", "CTS", "HCL.DE"]
 
headers = {
    'accept': '*/*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.9',
    'referer': 'https://www.google.com',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36 Edg/85.0.564.44'
}
 
for i in com:
 
        url = f"https://finance.yahoo.com/quote/{i}/news/"
        response = requests.get(url, headers = headers)
        response = response.content
        soup = BeautifulSoup(response, 'html.parser')
 
        for head in soup.find_all('h3', class_ = 'clamp'):
            H = head.get_text()
            # print(head.get_text())
 
        for para in soup.find('p', class_='clamp'):
            P = para.get_text()
            # print(para.get_text())
 
        for pub in soup.find_all('div', class_='publishing'):
            D = pub.get_text()
 
            company.append([H, P, D])
 
df = pd.DataFrame(company, columns=['Title', 'Description','Date and resource'])
df.to_csv("data_of_company.csv")
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
 
company = []
com = ["INFY.NS", "TCS", "CAP.PA", "CTS", "HCL.DE"]
 
headers = {
    'accept': '*/*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.9',
    'referer': 'https://www.google.com',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36 Edg/85.0.564.44'
}
 
for i in com:
 
        url = f"https://finance.yahoo.com/quote/{i}/news/"
        response = requests.get(url, headers = headers)
        response = response.content
        soup = BeautifulSoup(response, 'html.parser')
 
        for head in soup.find_all('h3', class_ = 'clamp'):
            H = head.get_text()
            # print(head.get_text())
 
        for para in soup.find('p', class_='clamp'):
            P = para.get_text()
            # print(para.get_text())
 
        for pub in soup.find_all('div', class_='publishing'):
            D = pub.get_text()
 
            company.append([H, P, D])
 
df = pd.DataFrame(company, columns=['Title', 'Description','Date and resource'])
df.to_csv("tcs.csv")
