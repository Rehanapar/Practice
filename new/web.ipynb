# %%
import requests
from bs4 import BeautifulSoup

def extract_data(url):
    response = requests.get(url = url).content
    # print(response)
    soup = BeautifulSoup(response, 'lxml')

    # table = soup.find("h2" , {"class" : "welcomepage_line1"})
    # table = soup.find("img" , {"class" : "load-false loaded"})
    # table = soup.find("h1" , {"id" : "res_title"})
    # table = soup.find("div" , {"class" : "content page-content"})
    # center = table.find("center").find("div")
    # print(table)
    # center = table.find("center").find("img")
    # print(center)"
    # table = soup.find("div" , {"class" : "bottom_nav_div"}, {"id" : "secondary-nav-2-1-page"})
    # table = soup.find("div" , {"class" : "bottom_nav_div"}, {"id" : "secondary-nav-2-1-page"}).find("ul")
    # li = table.find_all("li")
    # table = soup.find("div" , {"class" : "header-inner"}).find("div" , {"class" : "index"})
    # print(table.text.replace(' ',''))
    # for li in table.find_all('li'):
    # Find the <a> tag inside each <li>
        # a_tag = li.find('a')
        
        # # print(a_tag)

        # if a_tag:
        #     print(f"Text: {a_tag.text}")

    # print(li)
   
    # print(table)
    para = soup.find("p" , {"style" : "text-align:center;white-space:pre-wrap"}, {"class id"})
    print(para)
extract_data(url = "https://www.thepinkdoor.net/welcome/")
# Out:
# None

# %%
# !pip install bs4

# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = "https://kaashiv.com/"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")
# print(soup.find("title"))
# print(soup.find("title").text)
# results = soup.find(id = "hero")
# print(results)
print(soup.find_all("a", class_= "courses_content_title"))
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://kaashiv.com/"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")

# %%
import requests
from bs4 import BeautifulSoup

def extract_data(url):
    response = requests.get(url = url).content
    # print(response)
    soup = BeautifulSoup(response, 'lxml')
    print(soup)
    table = soup.find("div" , {"id" : "site"})
extract_data(url = "https://www.thepinkdoor.net/welcome/")
# Out:
# <!DOCTYPE html>
# <html class="touch-styles" lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- This is Squarespace. --><!-- thepinkdoor -->
# <base href=""/>
# <meta charset="utf-8"/>
# <title>The Pink Door</title>
# <meta content="Sec-CH-UA-Platform-Version, Sec-CH-UA-Model" http-equiv="Accept-CH"/><link href="https://images.squarespace-cdn.com/content/v1/574335cf59827e45443e86b7/1511210063260-KHKV0OENN5C8VKKW4O7C/favicon.ico?format=100w" rel="icon" type="image/x-icon"/>
# <link href="https://www.thepinkdoor.net" rel="canonical"/>
# <meta content="The Pink Door" property="og:site_name"/>
# <meta content="The Pink Door" property="og:title"/>
# <meta content="https://www.thepinkdoor.net" property="og:url"/>
# <meta content="website" property="og:type"/>
# ...

# %%
from bs4 import BeautifulSoup
import requests

url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of largest companies in the United States by revenue - Wikipedia</title>
# ...

# %%
soup.find('table')
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td><a href="/wiki/Retail" title="Retail">Retail</a>
# </td>
# <td style="text-align:center;">648,125
# </td>
# ...

# %%
soup.find_all('table')[1]
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD billions)
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Cargill" title="Cargill">Cargill</a>
# </td>
# <td>Food industry
# </td>
# <td style="text-align:center;">177
# </td>
# <td style="text-align:center;">160,000
# </td>
# <td><a href="/wiki/Minnetonka,_Minnesota" title="Minnetonka, Minnesota">Minnetonka, Minnesota</a>
# </td></tr>
# <tr>
# <td>2
# </td>
# <td><a class="mw-redirect" href="/wiki/Koch_Industries" title="Koch Industries">Koch Industries</a>
# </td>
# <td>Conglomerate
# </td>
# <td style="text-align:center;">125
# </td>
# <td style="text-align:center;">120,000
# </td>
# <td><a href="/wiki/Wichita,_Kansas" title="Wichita, Kansas">Wichita, Kansas</a>
# </td></tr>
# <tr>
# <td>3
# </td>
# ...

# %%
soup.find('table', class_ = 'wikitable sortable')
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td><a href="/wiki/Retail" title="Retail">Retail</a>
# </td>
# <td style="text-align:center;">648,125
# </td>
# ...

# %%
table = soup.find_all('table')[1]

# %%
print(table)
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD billions)
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Cargill" title="Cargill">Cargill</a>
# </td>
# <td>Food industry
# </td>
# <td style="text-align:center;">177
# </td>
# <td style="text-align:center;">160,000
# </td>
# <td><a href="/wiki/Minnetonka,_Minnesota" title="Minnetonka, Minnesota">Minnetonka, Minnesota</a>
# </td></tr>
# <tr>
# <td>2
# </td>
# <td><a class="mw-redirect" href="/wiki/Koch_Industries" title="Koch Industries">Koch Industries</a>
# </td>
# <td>Conglomerate
# </td>
# <td style="text-align:center;">125
# </td>
# <td style="text-align:center;">120,000
# </td>
# <td><a href="/wiki/Wichita,_Kansas" title="Wichita, Kansas">Wichita, Kansas</a>
# </td></tr>
# <tr>
# <td>3
# </td>
# ...

# %%
world_titles = table.find_all('th')
world_titles
# Out:
# [<th>Rank
#  </th>,
#  <th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Revenue <br/>(USD billions)
#  </th>,
#  <th>Employees
#  </th>,
#  <th>Headquarters
#  </th>]

# %%
world_table_titles = [title.text.strip() for title in world_titles]
print(world_table_titles)
# Out:
# ['Rank', 'Name', 'Industry', 'Revenue (USD billions)', 'Employees', 'Headquarters']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)

df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue (USD billions), Employees, Headquarters]
# Index: []

# %%
column_data = table.find_all('tr')
column_data
# Out:
# [<tr>
#  <th>Rank
#  </th>
#  <th>Name
#  </th>
#  <th>Industry
#  </th>
#  <th>Revenue <br/>(USD billions)
#  </th>
#  <th>Employees
#  </th>
#  <th>Headquarters
#  </th></tr>,
#  <tr>
#  <td>1
#  </td>
#  <td><a href="/wiki/Cargill" title="Cargill">Cargill</a>
#  </td>
#  <td>Food industry
#  </td>
#  <td style="text-align:center;">177
#  </td>
#  <td style="text-align:center;">160,000
#  </td>
#  <td><a href="/wiki/Minnetonka,_Minnesota" title="Minnetonka, Minnesota">Minnetonka, Minnesota</a>
#  </td></tr>,
#  <tr>
#  <td>2
#  </td>
#  <td><a class="mw-redirect" href="/wiki/Koch_Industries" title="Koch Industries">Koch Industries</a>
#  </td>
#  <td>Conglomerate
#  </td>
#  <td style="text-align:center;">125
#  </td>
#  <td style="text-align:center;">120,000
#  </td>
#  <td><a href="/wiki/Wichita,_Kansas" title="Wichita, Kansas">Wichita, Kansas</a>
#  </td></tr>,
#  <tr>
#  <td>3
#  </td>
# ...

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#   Rank                                Name                       Industry  \
# 0    1                             Cargill                  Food industry
# 1    2                     Koch Industries                   Conglomerate
# 2    3                Publix Super Markets                         Retail
# 3    4                  Mars, Incorporated                  Food industry
# 4    5                               H-E-B                         Retail
# 5    6                      Reyes Holdings                    Wholesaling
# 6    7                 Enterprise Holdings                     Car rental
# 7    8               C&S Wholesale Grocers                    Wholesaling
# 8    9                              Love's  Petroleum industry and Retail
# 9   10  Southern Glazer's Wine and Spirits                  Food industry
#
#   Revenue (USD billions) Employees             Headquarters
# 0                    177   160,000    Minnetonka, Minnesota
# ...

# %%
# https://cf-course-data.s3.us.cloud-object-storage-app-domain.cloud/IBM-DAO#@!EN-SkillsNetwork/labs/dataset/htmlcolor

# %%
# !pip install undetected-chromedriver
# Out:
# ...
#      ---------------------------------------- 0.0/65.4 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/65.4 kB ? eta -:--:--
#      ----------------- -------------------- 30.7/65.4 kB 330.3 kB/s eta 0:00:01
#      ----------------------- -------------- 41.0/65.4 kB 326.8 kB/s eta 0:00:01
#      -------------------------------------- 65.4/65.4 kB 320.7 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached selenium-4.24.0-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached trio-0.26.2-py3-none-any.whl.metadata (8.6 kB)
# ...
#   Using cached trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# ...
# Using cached selenium-4.24.0-py3-none-any.whl (9.6 MB)
# ...

# %%
import undetected_chromedriver as uc
from selenium.webdriver.common.by import By
import time

# Initialize undetected Chrome
options = uc.ChromeOptions()
options.add_argument("--headless")  # If you want to run headless
driver = uc.Chrome(options=options)

# Open the website
driver.get("https://example.com")

# Allow the page to load completely
time.sleep(3)

# Example: Extract some data (like headings) from the page
try:
    # Find elements using the appropriate selectors (like By.XPATH or By.CSS_SELECTOR)
    headings = driver.find_elements(By.TAG_NAME, "h1")
    for heading in headings:
        print("Heading:", heading.text)
finally:
    # Quit the driver
    driver.quit()
# Out:
# Heading: Example Domain
