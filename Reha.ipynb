# %%
import pandas as pd

# %%
df = pd.read_excel("EXCEL_catalog.xlsx")

column_mapping = {
    "ref":"CODE",
    "categorie":"TYPE",
    "title":"HEADING",
    "tags":"LABELS",
    "price":"COST",
    "description":"DETAILS"
}

df = df.rename(columns=column_mapping)

columns = ['CODE', 'TYPE', 'HEADING', 'LABELS', 'COST', 'DETAILS']

# Reorder the DataFrame using the new column order
df = df[columns]

df.to_csv("CSV_catalog.csv", index=False)

print(f"Data has been successfully imported")
# Out:
# Data has been successfully imported

# %%
df
# Out:
#            CODE      TYPE                                HEADING  \
# 0    Â B4084600     rings                              Love ring
# 1    Â B4084900     rings                              Love ring
# 2    Â B4084800     rings                              Love ring
# 3    Â B4084700     rings                              Love ring
# 4    Â B4085000     rings                      Love wedding band
# ..          ...       ...                                    ...
# 693  Â H8000466  earrings              Pluie de Cartier earrings
# 694  Â B8301416  earrings  Clash de Cartier earrings Small Model
# 695  Â B8301415  earrings  Clash de Cartier earrings Small Model
# 696  Â N8515173  earrings     Clash de Cartier earrings Diamonds
# 697  Â N8515218  earrings   Clash de Cartier earring Large Model
#
#                    LABELS     COST  \
# 0             yellow gold   1650.0
# 1                platinum   3650.0
# 2               pink gold   1650.0
# 3              white gold   1770.0
# ...

# %%
# Remove Special Characters
df["CODE"] = df["CODE"].str.strip("Â")
print("The Special Characters was removed")
# Out:
# The Special Characters was removed

# %%
df
# Out:
#           CODE      TYPE                                HEADING  \
# 0     B4084600     rings                              Love ring
# 1     B4084900     rings                              Love ring
# 2     B4084800     rings                              Love ring
# 3     B4084700     rings                              Love ring
# 4     B4085000     rings                      Love wedding band
# ..         ...       ...                                    ...
# 693   H8000466  earrings              Pluie de Cartier earrings
# 694   B8301416  earrings  Clash de Cartier earrings Small Model
# 695   B8301415  earrings  Clash de Cartier earrings Small Model
# 696   N8515173  earrings     Clash de Cartier earrings Diamonds
# 697   N8515218  earrings   Clash de Cartier earring Large Model
#
#                    LABELS     COST  \
# 0             yellow gold   1650.0
# 1                platinum   3650.0
# 2               pink gold   1650.0
# 3              white gold   1770.0
# ...

# %%
df.shape
# Out:
# (698, 6)

# %%
# Add Currency Symbol
df['COST'] = df['COST'].apply(lambda x: f'{x:.2f} INR')
print("The currency symbol was added")
# Out:
# The currency symbol was added

# %%
df
# Out:
#           CODE      TYPE                                HEADING  \
# 0     B4084600     rings                              Love ring
# 1     B4084900     rings                              Love ring
# 2     B4084800     rings                              Love ring
# 3     B4084700     rings                              Love ring
# 4     B4085000     rings                      Love wedding band
# ..         ...       ...                                    ...
# 693   H8000466  earrings              Pluie de Cartier earrings
# 694   B8301416  earrings  Clash de Cartier earrings Small Model
# 695   B8301415  earrings  Clash de Cartier earrings Small Model
# 696   N8515173  earrings     Clash de Cartier earrings Diamonds
# 697   N8515218  earrings   Clash de Cartier earring Large Model
#
#                    LABELS          COST  \
# 0             yellow gold   1650.00 INR
# 1                platinum   3650.00 INR
# 2               pink gold   1650.00 INR
# ...

# %%
default_costs = {
    'earrings': '5000 INR',
    'necklaces': '6000 INR',
    'rings': '7000 INR',
    'bracelets': '8000 INR'
}

def fill_cost(row):
    if pd.isna(row['COST']) or 'nan' in str(row['COST']):
        item_type = row['TYPE']
        return default_costs.get(item_type, row['COST'])  
    return row['COST']

# Apply the function to the DataFrame
df['COST'] = df.apply(fill_cost, axis=1)
print("Missing cost values were filled")
# Out:
# Missing cost values were filled

# %%
df
# Out:
#           CODE      TYPE                                HEADING  \
# 0     B4084600     rings                              Love ring
# 1     B4084900     rings                              Love ring
# 2     B4084800     rings                              Love ring
# 3     B4084700     rings                              Love ring
# 4     B4085000     rings                      Love wedding band
# ..         ...       ...                                    ...
# 693   H8000466  earrings              Pluie de Cartier earrings
# 694   B8301416  earrings  Clash de Cartier earrings Small Model
# 695   B8301415  earrings  Clash de Cartier earrings Small Model
# 696   N8515173  earrings     Clash de Cartier earrings Diamonds
# 697   N8515218  earrings   Clash de Cartier earring Large Model
#
#                    LABELS          COST  \
# 0             yellow gold   1650.00 INR
# 1                platinum   3650.00 INR
# 2               pink gold   1650.00 INR
# ...

# %%
stock_mapping = {
    'earrings': 15,
    'necklaces': 20,
    'rings': 25,
    'bracelets': 10
}
df['STOCKS'] = df['TYPE'].replace(stock_mapping)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8084\2483691644.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['STOCKS'] = df['TYPE'].replace(stock_mapping)

# %%
df
# Out:
#           CODE      TYPE                                HEADING  \
# 0     B4084600     rings                              Love ring
# 1     B4084900     rings                              Love ring
# 2     B4084800     rings                              Love ring
# 3     B4084700     rings                              Love ring
# 4     B4085000     rings                      Love wedding band
# ..         ...       ...                                    ...
# 693   H8000466  earrings              Pluie de Cartier earrings
# 694   B8301416  earrings  Clash de Cartier earrings Small Model
# 695   B8301415  earrings  Clash de Cartier earrings Small Model
# 696   N8515173  earrings     Clash de Cartier earrings Diamonds
# 697   N8515218  earrings   Clash de Cartier earring Large Model
#
#                    LABELS          COST  \
# 0             yellow gold   1650.00 INR
# 1                platinum   3650.00 INR
# 2               pink gold   1650.00 INR
# ...

# %%
column_to_insert = df.pop('STOCKS')

# 2. Insert the column at the desired position
df.insert(4, 'STOCKS', column_to_insert)

# %%
df
# Out:
#           CODE      TYPE                                HEADING  \
# 0     B4084600     rings                              Love ring
# 1     B4084900     rings                              Love ring
# 2     B4084800     rings                              Love ring
# 3     B4084700     rings                              Love ring
# 4     B4085000     rings                      Love wedding band
# ..         ...       ...                                    ...
# 693   H8000466  earrings              Pluie de Cartier earrings
# 694   B8301416  earrings  Clash de Cartier earrings Small Model
# 695   B8301415  earrings  Clash de Cartier earrings Small Model
# 696   N8515173  earrings     Clash de Cartier earrings Diamonds
# 697   N8515218  earrings   Clash de Cartier earring Large Model
#
#                    LABELS  STOCKS          COST  \
# 0             yellow gold      25   1650.00 INR
# 1                platinum      25   3650.00 INR
# 2               pink gold      25   1650.00 INR
# ...

# %%
df.to_csv("CSV_catalog.csv", index=False)

# %%
import pandas as pd

# Read the CSV file
# df = pd.read_csv("CSV_catalog.csv")

# Identify duplicate rows
# 'keep=False' marks all duplicates as True
duplicates = df[df.duplicated(keep=False)]

# Save the identified duplicates to a new CSV file
duplicates.to_csv("Duplicate.csv", index=False)

print("Duplicate entries have been successfully saved to 'Duplicate.csv'.")
# df.to_csv("Duplicate.csv", index = False)
# Out:
# Duplicate entries have been successfully saved to 'Duplicate.csv'.

# %%
df.to_csv("CSV_catalog.csv", index=False)

# %%
# Remove Duplicate Entries
df = df.drop_duplicates()
print("The Duplicates are removed")
df.to_csv("CSV_catalog.csv", index=False)
# Out:
# The Duplicates are removed

# %%
df
# Out:
#           CODE      TYPE                                HEADING  \
# 0     B4084600     rings                              Love ring
# 1     B4084900     rings                              Love ring
# 2     B4084800     rings                              Love ring
# 3     B4084700     rings                              Love ring
# 4     B4085000     rings                      Love wedding band
# ..         ...       ...                                    ...
# 693   H8000466  earrings              Pluie de Cartier earrings
# 694   B8301416  earrings  Clash de Cartier earrings Small Model
# 695   B8301415  earrings  Clash de Cartier earrings Small Model
# 696   N8515173  earrings     Clash de Cartier earrings Diamonds
# 697   N8515218  earrings   Clash de Cartier earring Large Model
#
#                    LABELS  STOCKS          COST  \
# 0             yellow gold      25   1650.00 INR
# 1                platinum      25   3650.00 INR
# 2               pink gold      25   1650.00 INR
# ...

# %%
# Sort by Cost (Low to High)
df
# Out:
#           CODE      TYPE                                HEADING  \
# 0     B4084600     rings                              Love ring
# 1     B4084900     rings                              Love ring
# 2     B4084800     rings                              Love ring
# 3     B4084700     rings                              Love ring
# 4     B4085000     rings                      Love wedding band
# ..         ...       ...                                    ...
# 693   H8000466  earrings              Pluie de Cartier earrings
# 694   B8301416  earrings  Clash de Cartier earrings Small Model
# 695   B8301415  earrings  Clash de Cartier earrings Small Model
# 696   N8515173  earrings     Clash de Cartier earrings Diamonds
# 697   N8515218  earrings   Clash de Cartier earring Large Model
#
#                    LABELS  STOCKS          COST  \
# 0             yellow gold      25   1650.00 INR
# 1                platinum      25   3650.00 INR
# 2               pink gold      25   1650.00 INR
# ...

# %%
df
# Out:
#           CODE      TYPE                                HEADING  \
# 0     B4084600     rings                              Love ring
# 1     B4084900     rings                              Love ring
# 2     B4084800     rings                              Love ring
# 3     B4084700     rings                              Love ring
# 4     B4085000     rings                      Love wedding band
# ..         ...       ...                                    ...
# 693   H8000466  earrings              Pluie de Cartier earrings
# 694   B8301416  earrings  Clash de Cartier earrings Small Model
# 695   B8301415  earrings  Clash de Cartier earrings Small Model
# 696   N8515173  earrings     Clash de Cartier earrings Diamonds
# 697   N8515218  earrings   Clash de Cartier earring Large Model
#
#                    LABELS  STOCKS          COST  \
# 0             yellow gold      25   1650.00 INR
# 1                platinum      25   3650.00 INR
# 2               pink gold      25   1650.00 INR
# ...

# %%
# # Remove 'INR' and convert to float
df['COST'] = df['COST'].replace({' INR': '', ',': ''}, regex=True).astype(float)

# Sort the DataFrame by 'TYPE' (product category) and 'COST'
# df_sorted = df.sort_values(by=['TYPE', 'COST'])
df = df.sort_values(by=['TYPE', 'COST'], ascending=[True, True])
# Write the sorted DataFrame to a new CSV file
df['COST'] = df['COST'].apply(lambda x: f'{x:.2f} INR')
print("The currency symbol was added")
df.to_csv("CSV_catalog.csv", index=False)
# Out:
# The currency symbol was added

# %%
df
# Out:
#           CODE       TYPE                         HEADING  \
# 346   B6016700  bracelets                Trinity bracelet
# 347   B6046200  bracelets                Trinity bracelet
# 359   B6045617  bracelets    Diamants LÃ©gers bracelet XS
# 360   B6045717  bracelets    Diamants LÃ©gers bracelet XS
# 361   B6045517  bracelets    Diamants LÃ©gers bracelet XS
# ..         ...        ...                             ...
# 37    H4078300      rings       PanthÃ¨re de Cartier ring
# 80    H4226000      rings  Faune et Flore de Cartier ring
# 69    H4179600      rings       PanthÃ¨re de Cartier ring
# 73    H4226300      rings       PanthÃ¨re de Cartier ring
# 70    H4183300      rings       PanthÃ¨re de Cartier ring
#
#                                             LABELS  STOCKS           COST  \
# 346             white gold, yellow gold, pink gold      10     580.00 INR
# 347                            white gold, ceramic      10     580.00 INR
# ...

# %%
df
# Out:
#           CODE       TYPE                         HEADING  \
# 346   B6016700  bracelets                Trinity bracelet
# 347   B6046200  bracelets                Trinity bracelet
# 359   B6045617  bracelets    Diamants LÃ©gers bracelet XS
# 360   B6045717  bracelets    Diamants LÃ©gers bracelet XS
# 361   B6045517  bracelets    Diamants LÃ©gers bracelet XS
# ..         ...        ...                             ...
# 37    H4078300      rings       PanthÃ¨re de Cartier ring
# 80    H4226000      rings  Faune et Flore de Cartier ring
# 69    H4179600      rings       PanthÃ¨re de Cartier ring
# 73    H4226300      rings       PanthÃ¨re de Cartier ring
# 70    H4183300      rings       PanthÃ¨re de Cartier ring
#
#                                             LABELS  STOCKS           COST  \
# 346             white gold, yellow gold, pink gold      10     580.00 INR
# 347                            white gold, ceramic      10     580.00 INR
# ...

# %%
# df['COST'] = df['COST'].replace({' INR': '', ',': ''}, regex=True).astype(float)

# # Sort the DataFrame by 'TYPE' (product category) and 'COST' within each type
# df_sorted = df.sort_values(by=['TYPE', 'COST'])

# # Write the sorted DataFrame to a new CSV file
# df_sorted.to_csv("CSV_catalog_sorted.csv", index=False)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8084\481787728.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['COST'] = df['COST'].replace({' INR': '', ',': ''}, regex=True).astype(float)

# %%
df.to_csv("CSV_catalog.csv", index=False)

# %%
import pandas as pd

# Read the CSV file
# df = pd.read_csv("CSV_catalog.csv")

# Identify duplicate rows
# 'keep=False' marks all duplicates as True
duplicate = df[df.duplicated(keep=False)]

# Save the identified duplicates to a new CSV file
duplicate.to_csv("Duplicate.csv", index=False)

print("Duplicate entries have been successfully saved to 'Duplicates.csv'.")
# Out:
# Duplicate entries have been successfully saved to 'Duplicates.csv'.

# %%
df
# Out:
#           CODE       TYPE                         HEADING  \
# 0     B6016700  bracelets                Trinity bracelet
# 1     B6046200  bracelets                Trinity bracelet
# 2     B6045617  bracelets    Diamants LÃ©gers bracelet XS
# 3     B6045717  bracelets    Diamants LÃ©gers bracelet XS
# 4     B6045517  bracelets    Diamants LÃ©gers bracelet XS
# ..         ...        ...                             ...
# 684   H4078300      rings       PanthÃ¨re de Cartier ring
# 685   H4226000      rings  Faune et Flore de Cartier ring
# 686   H4179600      rings       PanthÃ¨re de Cartier ring
# 687   H4226300      rings       PanthÃ¨re de Cartier ring
# 688   H4183300      rings       PanthÃ¨re de Cartier ring
#
#                                             LABELS  STOCKS           COST  \
# 0               white gold, yellow gold, pink gold      10     580.00 INR
# 1                              white gold, ceramic      10     580.00 INR
# ...

# %%
# Share your python script file with output files after completion
duplicate
# Out:
# Empty DataFrame
# Columns: [CODE, TYPE, HEADING, LABELS, STOCKS, COST, DETAILS]
# Index: []

# %%
df
# Out:
#           CODE       TYPE                         HEADING  \
# 0     B6016700  bracelets                Trinity bracelet
# 1     B6046200  bracelets                Trinity bracelet
# 2     B6045617  bracelets    Diamants LÃ©gers bracelet XS
# 3     B6045717  bracelets    Diamants LÃ©gers bracelet XS
# 4     B6045517  bracelets    Diamants LÃ©gers bracelet XS
# ..         ...        ...                             ...
# 684   H4078300      rings       PanthÃ¨re de Cartier ring
# 685   H4226000      rings  Faune et Flore de Cartier ring
# 686   H4179600      rings       PanthÃ¨re de Cartier ring
# 687   H4226300      rings       PanthÃ¨re de Cartier ring
# 688   H4183300      rings       PanthÃ¨re de Cartier ring
#
#                                             LABELS  STOCKS           COST  \
# 0               white gold, yellow gold, pink gold      10     580.00 INR
# 1                              white gold, ceramic      10     580.00 INR
# ...

# %%
df
# Out:
#           CODE       TYPE                         HEADING  \
# 0     B6016700  bracelets                Trinity bracelet
# 1     B6046200  bracelets                Trinity bracelet
# 2     B6045617  bracelets    Diamants LÃ©gers bracelet XS
# 3     B6045717  bracelets    Diamants LÃ©gers bracelet XS
# 4     B6045517  bracelets    Diamants LÃ©gers bracelet XS
# ..         ...        ...                             ...
# 684   H4078300      rings       PanthÃ¨re de Cartier ring
# 685   H4226000      rings  Faune et Flore de Cartier ring
# 686   H4179600      rings       PanthÃ¨re de Cartier ring
# 687   H4226300      rings       PanthÃ¨re de Cartier ring
# 688   H4183300      rings       PanthÃ¨re de Cartier ring
#
#                                             LABELS  STOCKS           COST  \
# 0               white gold, yellow gold, pink gold      10     580.00 INR
# 1                              white gold, ceramic      10     580.00 INR
# ...

# %%
# df_sorted.index = range(0, 689)

# df_sorted


# # Save the DataFrame to a CSV file with the new index
# df_sorted.to_csv("CSV_catalog", index=True)

# print("Data has been successfully exported with the index replaced from 100 to 200.")
# Out:
#           CODE       TYPE                         HEADING  \
# 0     B6016700  bracelets                Trinity bracelet
# 1     B6046200  bracelets                Trinity bracelet
# 2     B6045617  bracelets    Diamants LÃ©gers bracelet XS
# 3     B6045717  bracelets    Diamants LÃ©gers bracelet XS
# 4     B6045517  bracelets    Diamants LÃ©gers bracelet XS
# ..         ...        ...                             ...
# 684   H4078300      rings       PanthÃ¨re de Cartier ring
# 685   H4226000      rings  Faune et Flore de Cartier ring
# 686   H4179600      rings       PanthÃ¨re de Cartier ring
# 687   H4226300      rings       PanthÃ¨re de Cartier ring
# 688   H4183300      rings       PanthÃ¨re de Cartier ring
#
#                                             LABELS  STOCKS      COST  \
# 0               white gold, yellow gold, pink gold      10     580.0
# 1                              white gold, ceramic      10     580.0
# ...

# %%
df_sorted
# Out:
#           CODE       TYPE                         HEADING  \
# 0     B6016700  bracelets                Trinity bracelet
# 1     B6046200  bracelets                Trinity bracelet
# 2     B6045617  bracelets    Diamants LÃ©gers bracelet XS
# 3     B6045717  bracelets    Diamants LÃ©gers bracelet XS
# 4     B6045517  bracelets    Diamants LÃ©gers bracelet XS
# ..         ...        ...                             ...
# 684   H4078300      rings       PanthÃ¨re de Cartier ring
# 685   H4226000      rings  Faune et Flore de Cartier ring
# 686   H4179600      rings       PanthÃ¨re de Cartier ring
# 687   H4226300      rings       PanthÃ¨re de Cartier ring
# 688   H4183300      rings       PanthÃ¨re de Cartier ring
#
#                                             LABELS  STOCKS      COST  \
# 0               white gold, yellow gold, pink gold      10     580.0
# 1                              white gold, ceramic      10     580.0
# ...

# %%
df.insert(0, 'SR.No', range(1001, 1690))

# %%
df
# Out:
#      SR.No       CODE       TYPE                         HEADING  \
# 0     1001   B6016700  bracelets                Trinity bracelet
# 1     1002   B6046200  bracelets                Trinity bracelet
# 2     1003   B6045617  bracelets    Diamants LÃ©gers bracelet XS
# 3     1004   B6045717  bracelets    Diamants LÃ©gers bracelet XS
# 4     1005   B6045517  bracelets    Diamants LÃ©gers bracelet XS
# ..     ...        ...        ...                             ...
# 684   1685   H4078300      rings       PanthÃ¨re de Cartier ring
# 685   1686   H4226000      rings  Faune et Flore de Cartier ring
# 686   1687   H4179600      rings       PanthÃ¨re de Cartier ring
# 687   1688   H4226300      rings       PanthÃ¨re de Cartier ring
# 688   1689   H4183300      rings       PanthÃ¨re de Cartier ring
#
#                                             LABELS  STOCKS           COST  \
# 0               white gold, yellow gold, pink gold      10     580.00 INR
# ...

# %%
df
# Out:
#      SR.No       CODE       TYPE                         HEADING  \
# 0     1001   B6016700  bracelets                Trinity bracelet
# 1     1002   B6046200  bracelets                Trinity bracelet
# 2     1003   B6045617  bracelets    Diamants LÃ©gers bracelet XS
# 3     1004   B6045717  bracelets    Diamants LÃ©gers bracelet XS
# 4     1005   B6045517  bracelets    Diamants LÃ©gers bracelet XS
# ..     ...        ...        ...                             ...
# 684   1685   H4078300      rings       PanthÃ¨re de Cartier ring
# 685   1686   H4226000      rings  Faune et Flore de Cartier ring
# 686   1687   H4179600      rings       PanthÃ¨re de Cartier ring
# 687   1688   H4226300      rings       PanthÃ¨re de Cartier ring
# 688   1689   H4183300      rings       PanthÃ¨re de Cartier ring
#
#                                             LABELS  STOCKS           COST  \
# 0               white gold, yellow gold, pink gold      10     580.00 INR
# ...

# %%
df.to_csv("CSV_catalog.csv", index=False)

# %%
df
# Out:
#      SR.No       CODE       TYPE                         HEADING  \
# 0     1001   B6016700  bracelets                Trinity bracelet
# 1     1002   B6046200  bracelets                Trinity bracelet
# 2     1003   B6045617  bracelets    Diamants LÃ©gers bracelet XS
# 3     1004   B6045717  bracelets    Diamants LÃ©gers bracelet XS
# 4     1005   B6045517  bracelets    Diamants LÃ©gers bracelet XS
# ..     ...        ...        ...                             ...
# 684   1685   H4078300      rings       PanthÃ¨re de Cartier ring
# 685   1686   H4226000      rings  Faune et Flore de Cartier ring
# 686   1687   H4179600      rings       PanthÃ¨re de Cartier ring
# 687   1688   H4226300      rings       PanthÃ¨re de Cartier ring
# 688   1689   H4183300      rings       PanthÃ¨re de Cartier ring
#
#                                             LABELS  STOCKS           COST  \
# 0               white gold, yellow gold, pink gold      10     580.00 INR
# ...
