# %%
import pandas as pd

# %%
df = pd.read_csv("news_sentiment_analysis 1.csv")
df
# Out:
#                  Source           Author  \
# 0               stgnews   Bridger Palmer
# 1         Zimbabwe Mail   Staff Reporter
# 2             4-traders              NaN
# 3             4-traders              NaN
# 4                PLANET              NaN
# ...                 ...              ...
# 3495       etfdailynews  MarketBeat News
# 3496       etfdailynews  MarketBeat News
# 3497       etfdailynews  MarketBeat News
# 3498  finanznachrichten              NaN
# 3499       etfdailynews  MarketBeat News
#
#                                                   Title  \
# 0     Pine View High teacher wins Best in State awar...
# 1     Businesses Face Financial Strain Amid Liquidit...
# 2     Musk donates to super pac working to elect Tru...
# 3     US FTC issues warning to franchisors over unfa...
# 4                             Rooftop solar's dark side
# ...                                                 ...
# 3495  Arrow Electronics, Inc. (NYSE:ARW) Shares Purc...
# ...

# %%
date = pd.to_datetime('2024-08-29')
print(date)
# Out:
# 2024-08-29 00:00:00

# %% [raw]
# date_range = pd.date_range(start='2024-08-01', end='2024-08-10', freq='D')
# print(date_range)

# %%
date_range = pd.date_range(start='2024-08-01', end='2024-08-10', freq='D')
print(date_range)
# Out:
# DatetimeIndex(['2024-08-01', '2024-08-02', '2024-08-03', '2024-08-04',
#                '2024-08-05', '2024-08-06', '2024-08-07', '2024-08-08',
#                '2024-08-09', '2024-08-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.DatetimeIndex(['2024-08-01', '2024-08-02', '2024-08-03'])
print(dates)
# Out:
# DatetimeIndex(['2024-08-01', '2024-08-02', '2024-08-03'], dtype='datetime64[ns]', freq=None)

# %%
df = pd.read_excel('matches.xlsx')
df
# Out:
#       Unnamed: 0       date           time            comp         round  day  \
# 0              0 2020-09-21  20:15 (21:15)  Premier League   Matchweek 2  Mon
# 1              2 2020-09-27  16:30 (17:30)  Premier League   Matchweek 3  Sun
# 2              4 2020-10-03  17:30 (18:30)  Premier League   Matchweek 4  Sat
# 3              5 2020-10-17  17:30 (18:30)  Premier League   Matchweek 5  Sat
# 4              7 2020-10-24  12:30 (13:30)  Premier League   Matchweek 6  Sat
# ...          ...        ...            ...             ...           ...  ...
# 4783          87 2020-07-07  18:00 (19:00)  Premier League  Matchweek 34  Tue
# 4784          88 2020-07-11  12:30 (13:30)  Premier League  Matchweek 35  Sat
# 4785          89 2020-07-14  20:15 (21:15)  Premier League  Matchweek 36  Tue
# 4786          90 2020-07-18  17:30 (18:30)  Premier League  Matchweek 37  Sat
# 4787          91 2020-07-26  16:00 (17:00)  Premier League  Matchweek 38  Sun
#
# ...

# %%
df.to_csv('matches.csv', index=False)

# %%
df
# Out:
#       Unnamed: 0       date           time            comp         round  day  \
# 0              0 2020-09-21  20:15 (21:15)  Premier League   Matchweek 2  Mon
# 1              2 2020-09-27  16:30 (17:30)  Premier League   Matchweek 3  Sun
# 2              4 2020-10-03  17:30 (18:30)  Premier League   Matchweek 4  Sat
# 3              5 2020-10-17  17:30 (18:30)  Premier League   Matchweek 5  Sat
# 4              7 2020-10-24  12:30 (13:30)  Premier League   Matchweek 6  Sat
# ...          ...        ...            ...             ...           ...  ...
# 4783          87 2020-07-07  18:00 (19:00)  Premier League  Matchweek 34  Tue
# 0              0  2020-09-21  20:15 (21:15)  Premier League   Matchweek 2
# 1              2  2020-09-27  16:30 (17:30)  Premier League   Matchweek 3
# 2              4  2020-10-03  17:30 (18:30)  Premier League   Matchweek 4
# 3              5  2020-10-17  17:30 (18:30)  Premier League   Matchweek 5
# 4              7  2020-10-24  12:30 (13:30)  Premier League   Matchweek 6
# ...          ...         ...            ...             ...           ...
# 4783          87  2020-07-07  18:00 (19:00)  Premier League  Matchweek 34
# 4784          88  2020-07-11  12:30 (13:30)  Premier League  Matchweek 35
# 4785          89  2020-07-14  20:15 (21:15)  Premier League  Matchweek 36
# 4786          90  2020-07-18  17:30 (18:30)  Premier League  Matchweek 37
# 4787          91  2020-07-26  16:00 (17:00)  Premier League  Matchweek 38
#
#       day venue result  gf  ga  ...  match report  notes  sh  sot  dist fk pk  \
# ...

# %%
new_ana = pd.read_csv('news_sentiment_analysis 1.csv')

# %%
new_ana
# Out:
#                  Source           Author  \
# 0               stgnews   Bridger Palmer
# 1         Zimbabwe Mail   Staff Reporter
# 2             4-traders              NaN
# 3             4-traders              NaN
# 4                PLANET              NaN
# ...                 ...              ...
# 3495       etfdailynews  MarketBeat News
# 3496       etfdailynews  MarketBeat News
# 3497       etfdailynews  MarketBeat News
# 3498  finanznachrichten              NaN
# 3499       etfdailynews  MarketBeat News
#
#                                                   Title  \
# 0     Pine View High teacher wins Best in State awar...
# 1     Businesses Face Financial Strain Amid Liquidit...
# 2     Musk donates to super pac working to elect Tru...
# 3     US FTC issues warning to franchisors over unfa...
# 4                             Rooftop solar's dark side
# ...                                                 ...
# 3495  Arrow Electronics, Inc. (NYSE:ARW) Shares Purc...
# ...

# %%
call = pd.read_excel(r"C:\Users\admin\Downloads\Customer Call List.xlsx")
call
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df = call.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df = df.drop(columns = 'Not_Useful_Column')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df["Last_Name"] = df["Last_Name"].str.strip("123._/")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
df['Phone_Number'] = df['Phone_Number'].astype(str).str.replace(r'[^\d]', '', regex=True)
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   7066950392
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# 17        1018      Clark        Kent   7066950392
# ...

# %%
df['Phone_Number'] = df['Phone_Number'].replace('', 'UNKNOWN')
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   7066950392
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger      UNKNOWN
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN      UNKNOWN
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee      UNKNOWN
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# ...

# %%
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   7066950392
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger      UNKNOWN
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN      UNKNOWN
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee      UNKNOWN
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# ...

# %%
df[["Street_Address", "State", "Zip_Code"]] = df["Address"].str.split(',',2, expand=True)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[212], line 1
# ----> 1 df[["Street_Address", "State", "Zip_Code"]] = df["Address"].str.split(',',2, expand=True)
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:137, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     132     msg = (
#     133         f"Cannot use .str.{func_name} with values of "
#     134         f"inferred dtype '{self._inferred_dtype}'."
#     135     )
#     136     raise TypeError(msg)
# --> 137 return func(self, *args, **kwargs)
#
# TypeError: StringMethods.split() takes from 1 to 2 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given
